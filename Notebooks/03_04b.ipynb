# %% [markdown]
# # How to Visualize Data in Python

# %% [markdown]
# ## Learning Objectives
# When exploring data, one of the most important things we can do is visualize it so we can better understand it. Like the popular saying "*A picture is worth a thousand words*”, visualizations are sometimes more useful than summary statistics in helping us understand our data. This is because visualizations are a great tool for asking and answering questions about data. Depending on the type of question we are trying to answer, there are four major types of visualizations we could use. They are relationship, distribution, comparison and composition. By the end of this tutorial, you will have learned:
#
# + how to create a relationship visualization
# + how to create a distribution visualization
# + how to create a comparison visualization
# + how to create a composition visualization

# %%
# %matplotlib inline

# %% [markdown]
# Let's import and preview the data we will use to illustrate how to visualize data.

# %%
import pandas as pd
vehicles = pd.read_csv("vehicles.csv")
vehicles.head()
# Out:
#    citympg  cylinders  displacement             drive  highwaympg      make  \
# 0     14.0          6           4.1     2-Wheel Drive        19.0     Buick
# 1     14.0          8           5.0     2-Wheel Drive        20.0     Buick
# 2     18.0          8           5.7     2-Wheel Drive        26.0     Buick
# 3     21.0          6           4.3  Rear-Wheel Drive        31.0  Cadillac
# 4     14.0          8           4.1  Rear-Wheel Drive        19.0  Cadillac
#
#                      model       class  year transmissiontype  \
# 0      Electra/Park Avenue  Large Cars  1984        Automatic
# 1      Electra/Park Avenue  Large Cars  1984        Automatic
# 2      Electra/Park Avenue  Large Cars  1984        Automatic
# 3  Fleetwood/DeVille (FWD)  Large Cars  1984        Automatic
# 4   Brougham/DeVille (RWD)  Large Cars  1984        Automatic
#
#    transmissionspeeds  co2emissions
# 0                   4    555.437500
# 1                   4    555.437500
# 2                   4    484.761905
# 3                   4    424.166667
# 4                   4    555.437500

# %% [markdown]
# ## How to create a Relationship Visualization

# %%
vehicles.plot(kind = 'scatter', x = 'citympg', y = 'co2emissions')

# %% [markdown]
# ## How to create a Distribution Visualization

# %%
vehicles['co2emissions'].plot(kind = 'hist')

# %% [markdown]
# ## How to create a Comparision Visualization

# %%
vehicles.pivot(columns = 'drive',values = 'co2emissions')
# Out:
# drive  2-Wheel Drive  4-Wheel Drive  All-Wheel Drive  Front-Wheel Drive  \
# 0         555.437500            NaN              NaN                NaN
# 1         555.437500            NaN              NaN                NaN
# 2         484.761905            NaN              NaN                NaN
# 3                NaN            NaN              NaN                NaN
# 4                NaN            NaN              NaN                NaN
# 5                NaN            NaN              NaN                NaN
# 6                NaN            NaN              NaN                NaN
# 7         467.736842            NaN              NaN                NaN
# 8         423.190476            NaN              NaN                NaN
# 9         444.350000            NaN              NaN                NaN
# 10        467.736842            NaN              NaN                NaN
# 11        493.722222            NaN              NaN                NaN
# 12        444.350000            NaN              NaN                NaN
# 13        467.736842            NaN              NaN                NaN
# 14        467.736842            NaN              NaN                NaN
# 15        424.166667            NaN              NaN                NaN
# 16        444.350000            NaN              NaN                NaN
# 17        467.736842            NaN              NaN                NaN
# 18        493.722222            NaN              NaN                NaN
# 19        444.350000            NaN              NaN                NaN
# 20        467.736842            NaN              NaN                NaN
# 21        444.350000            NaN              NaN                NaN
# 22        467.736842            NaN              NaN                NaN
# 23        423.190476            NaN              NaN                NaN
# 24        467.736842            NaN              NaN                NaN
# 25        493.722222            NaN              NaN                NaN
# 26        467.736842            NaN              NaN                NaN
# 27        444.350000            NaN              NaN                NaN
# 28        467.736842            NaN              NaN                NaN
# 29        424.166667            NaN              NaN                NaN
# ...              ...            ...              ...                ...
# 36949            NaN            NaN              NaN                NaN
# 36950            NaN            NaN              NaN                NaN
# 36951            NaN            NaN              NaN                NaN
# 36952            NaN            NaN              NaN                NaN
# 36953            NaN            NaN              NaN                NaN
# 36954            NaN            NaN              NaN                NaN
# 36955            NaN            NaN              NaN                NaN
# 36956            NaN            NaN              NaN                NaN
# 36957            NaN            NaN              NaN                NaN
# 36958            NaN            NaN              NaN                NaN
# 36959            NaN            NaN              NaN                NaN
# 36960            NaN            NaN              NaN                NaN
# 36961            NaN            NaN              NaN                NaN
# 36962            NaN            NaN              NaN                NaN
# 36963            NaN            NaN              NaN                NaN
# 36964            NaN            NaN              NaN                NaN
# 36965            NaN            NaN              NaN                NaN
# 36966            NaN            NaN              NaN                NaN
# 36967            NaN            NaN              NaN                NaN
# 36968            NaN            NaN              NaN                NaN
# 36969            NaN            NaN              NaN                NaN
# 36970            NaN            NaN              NaN                NaN
# 36971            NaN            NaN              NaN                NaN
# 36972            NaN            NaN              NaN                NaN
# 36973            NaN            NaN              NaN                NaN
# 36974            NaN            NaN              NaN                NaN
# 36975            NaN            NaN              NaN                NaN
# 36976            NaN            NaN              NaN                NaN
# 36977            NaN            NaN              NaN                NaN
# 36978            NaN            NaN              NaN                NaN
#
# drive  Rear-Wheel Drive
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3            424.166667
# 4            555.437500
# 5            484.761905
# 6            555.437500
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# ...                 ...
# 36949        401.000000
# 36950        450.000000
# 36951        433.000000
# 36952        411.000000
# 36953        390.000000
# 36954        390.000000
# 36955        407.000000
# 36956        407.000000
# 36957        379.000000
# 36958        476.000000
# 36959        476.000000
# 36960        485.000000
# 36961        485.000000
# 36962        447.000000
# 36963        426.000000
# 36964        501.000000
# 36965        495.000000
# 36966        501.000000
# 36967        495.000000
# 36968        486.000000
# 36969        486.000000
# 36970        490.000000
# 36971        541.000000
# 36972        487.000000
# 36973        468.000000
# 36974        442.000000
# 36975        466.000000
# 36976        503.000000
# 36977        661.000000
# 36978        546.000000
#
# [36979 rows x 5 columns]

# %%
vehicles.pivot(columns = 'drive', values = 'co2emissions').plot(kind = 'box',figsize = (10,6))

# %% [markdown]
# ## How to create a Composition Visualization

# %%
vehicles.groupby('year')['drive'].value_counts()
# Out:
# year  drive
# 1984  2-Wheel Drive        477
#       All-Wheel Drive      301
#       Rear-Wheel Drive       4
# 1985  Rear-Wheel Drive     772
#       Front-Wheel Drive    672
#       All-Wheel Drive      255
# 1986  Rear-Wheel Drive     576
#       Front-Wheel Drive    430
#       All-Wheel Drive      202
#       4-Wheel Drive          1
# 1987  Rear-Wheel Drive     557
#       Front-Wheel Drive    470
#       All-Wheel Drive      220
# 1988  Rear-Wheel Drive     468
#       Front-Wheel Drive    447
#       All-Wheel Drive      215
# 1989  Rear-Wheel Drive     480
#       Front-Wheel Drive    445
#       All-Wheel Drive      227
# 1990  Front-Wheel Drive    422
#       Rear-Wheel Drive     413
#       All-Wheel Drive      241
# 1991  Rear-Wheel Drive     456
#       Front-Wheel Drive    431
#       All-Wheel Drive      243
# 1992  Front-Wheel Drive    455
#       Rear-Wheel Drive     432
#       All-Wheel Drive      232
# 1993  Front-Wheel Drive    470
#       Rear-Wheel Drive     401
#                           ...
# 2011  All-Wheel Drive      225
#       4-Wheel Drive        134
# 2012  Rear-Wheel Drive     381
#       Front-Wheel Drive    348
#       All-Wheel Drive      203
#       4-Wheel Drive        146
# 2013  Front-Wheel Drive    381
#       Rear-Wheel Drive     356
#       All-Wheel Drive      239
#       4-Wheel Drive        128
# 2014  Front-Wheel Drive    379
#       Rear-Wheel Drive     352
#       All-Wheel Drive      259
#       4-Wheel Drive        151
# 2015  Front-Wheel Drive    377
#       Rear-Wheel Drive     377
#       All-Wheel Drive      286
#       4-Wheel Drive        163
# 2016  Front-Wheel Drive    370
#       Rear-Wheel Drive     350
#       All-Wheel Drive      289
#       4-Wheel Drive        163
# 2017  Front-Wheel Drive    348
#       Rear-Wheel Drive     346
#       All-Wheel Drive      334
#       4-Wheel Drive        173
# 2018  All-Wheel Drive      245
#       Rear-Wheel Drive     230
#       Front-Wheel Drive    193
#       4-Wheel Drive        124
# Name: drive, Length: 123, dtype: int64

# %%
vehicles.groupby('year')['drive'].value_counts().unstack()
# Out:
# drive  2-Wheel Drive  4-Wheel Drive  All-Wheel Drive  Front-Wheel Drive  \
# year
# 1984           477.0            NaN            301.0                NaN
# 1985             NaN            NaN            255.0              672.0
# 1986             NaN            1.0            202.0              430.0
# 1987             NaN            NaN            220.0              470.0
# 1988             NaN            NaN            215.0              447.0
# 1989             NaN            NaN            227.0              445.0
# 1990             NaN            NaN            241.0              422.0
# 1991             NaN            NaN            243.0              431.0
# 1992             NaN            NaN            232.0              455.0
# 1993             NaN            NaN            220.0              470.0
# 1994             NaN            NaN            211.0              410.0
# 1995             1.0            NaN            196.0              400.0
# 1996             NaN            NaN            153.0              353.0
# 1997             NaN           10.0            150.0              324.0
# 1998             NaN            NaN            177.0              348.0
# 1999             8.0            NaN            187.0              362.0
# 2000             NaN            NaN            179.0              346.0
# 2001             NaN            NaN            219.0              358.0
# 2002             2.0            NaN            250.0              372.0
# 2003             NaN            NaN            298.0              354.0
# 2004             NaN            1.0            343.0              378.0
# 2005             1.0            NaN            367.0              391.0
# 2006             2.0            NaN            354.0              344.0
# 2007             NaN            2.0            369.0              328.0
# 2008             NaN            NaN            388.0              343.0
# 2009             NaN            NaN            392.0              347.0
# 2010             NaN          153.0            202.0              352.0
# 2011             NaN          134.0            225.0              326.0
# 2012             NaN          146.0            203.0              348.0
# 2013             NaN          128.0            239.0              381.0
# 2014             NaN          151.0            259.0              379.0
# 2015             NaN          163.0            286.0              377.0
# 2016             NaN          163.0            289.0              370.0
# 2017             NaN          173.0            334.0              348.0
# 2018             NaN          124.0            245.0              193.0
#
# drive  Rear-Wheel Drive
# year
# 1984                4.0
# 1985              772.0
# 1986              576.0
# 1987              557.0
# 1988              468.0
# 1989              480.0
# 1990              413.0
# 1991              456.0
# 1992              432.0
# 1993              401.0
# 1994              361.0
# 1995              370.0
# 1996              266.0
# 1997              277.0
# 1998              283.0
# 1999              287.0
# 2000              310.0
# 2001              324.0
# 2002              338.0
# 2003              374.0
# 2004              383.0
# 2005              382.0
# 2006              379.0
# 2007              389.0
# 2008              410.0
# 2009              390.0
# 2010              345.0
# 2011              375.0
# 2012              381.0
# 2013              356.0
# 2014              352.0
# 2015              377.0
# 2016              350.0
# 2017              346.0
# 2018              230.0

# %%
vehicles.groupby('year')['drive'].value_counts().unstack().plot(kind = 'bar',stacked = True, figsize = (10,6))
