# %% [markdown]
# # How to Sample Data in Python

# %% [markdown]
# ## Learning Objectives
# In order to get an unbiased assessment of the performance of a supervised machine learning model, we need to evaluate it based on data that it did not previously encounter during the training process. To accomplish this, we must first split our data into a training subset and a test subset prior to the model build stage. One common way to split data in this fashion is by creating non-overlapping subsets of the original data using one of several **sampling** approaches. By the end of the tutorial, you will have learned:
#
# + how to split data using simple random sampling
# + how to split data using stratified random sampling

# %%
import pandas as pd
vehicles = pd.read_csv("vehicles.csv")
vehicles
# Out:
#        citympg  cylinders  displacement             drive  highwaympg  \
# 0         14.0          6           4.1     2-Wheel Drive        19.0
# 1         14.0          8           5.0     2-Wheel Drive        20.0
# 2         18.0          8           5.7     2-Wheel Drive        26.0
# 3         21.0          6           4.3  Rear-Wheel Drive        31.0
# 4         14.0          8           4.1  Rear-Wheel Drive        19.0
# 5         18.0          8           5.7  Rear-Wheel Drive        26.0
# 6         14.0          8           4.1  Rear-Wheel Drive        19.0
# 7         18.0          4           2.4     2-Wheel Drive        21.0
# 8         18.0          4           2.2     2-Wheel Drive        24.0
# 9         20.0          4           2.0     2-Wheel Drive        21.0
# 10        18.0          4           2.0     2-Wheel Drive        20.0
# 11        18.0          4           2.6     2-Wheel Drive        19.0
# 12        19.0          4           2.6     2-Wheel Drive        20.0
# 13        18.0          4           2.3     2-Wheel Drive        22.0
# 14        18.0          4           2.0     2-Wheel Drive        20.0
# 15        23.0          4           2.2     2-Wheel Drive        24.0
# 16        20.0          4           2.0     2-Wheel Drive        21.0
# 17        18.0          4           2.0     2-Wheel Drive        20.0
# 18        18.0          4           2.6     2-Wheel Drive        19.0
# 19        19.0          4           2.6     2-Wheel Drive        20.0
# 20        18.0          4           2.0     2-Wheel Drive        20.0
# 21        18.0          4           2.0     2-Wheel Drive        24.0
# 22        18.0          4           2.4     2-Wheel Drive        21.0
# 23        19.0          4           2.2     2-Wheel Drive        24.0
# 24        18.0          4           2.0     2-Wheel Drive        20.0
# 25        18.0          4           2.6     2-Wheel Drive        19.0
# 26        18.0          4           2.3     2-Wheel Drive        20.0
# 27        18.0          4           2.0     2-Wheel Drive        24.0
# 28        18.0          4           2.0     2-Wheel Drive        21.0
# 29        23.0          4           2.2     2-Wheel Drive        24.0
# ...        ...        ...           ...               ...         ...
# 36949     20.0          4           2.5  Rear-Wheel Drive        26.0
# 36950     17.0          6           3.0  Rear-Wheel Drive        24.0
# 36951     18.0          6           3.7  Rear-Wheel Drive        25.0
# 36952     19.0          6           3.7  Rear-Wheel Drive        26.0
# 36953     20.0          6           3.0  Rear-Wheel Drive        28.0
# 36954     20.0          6           3.0  Rear-Wheel Drive        28.0
# 36955     19.0          6           3.0  Rear-Wheel Drive        27.0
# 36956     19.0          6           3.0  Rear-Wheel Drive        27.0
# 36957     20.0          6           3.0  Rear-Wheel Drive        29.0
# 36958     16.0          6           3.0  Rear-Wheel Drive        24.0
# 36959     16.0          6           3.0  Rear-Wheel Drive        24.0
# 36960     15.0          6           3.0  Rear-Wheel Drive        24.0
# 36961     15.0          6           3.0  Rear-Wheel Drive        24.0
# 36962     17.0          6           3.7  Rear-Wheel Drive        24.0
# 36963     18.0          6           3.7  Rear-Wheel Drive        26.0
# 36957  Mercedes-Benz                 AMG SLC43  Two Seaters  2018
# 36958         Jaguar              F-Type Coupe  Two Seaters  2018
# 36959         Jaguar        F-Type Convertible  Two Seaters  2018
# 36960         Jaguar            F-Type S Coupe  Two Seaters  2018
# 36961         Jaguar      F-Type S Convertible  Two Seaters  2018
# 36962         Nissan             370Z Roadster  Two Seaters  2018
# 36963         Nissan                      370Z  Two Seaters  2018
# 36964        Ferrari                   488 GTB  Two Seaters  2018
# 36965        Ferrari                   488 GTB  Two Seaters  2018
# 36966        Ferrari                488 Spider  Two Seaters  2018
# 36967        Ferrari                488 Spider  Two Seaters  2018
# 36968  Mercedes-Benz            AMG GT S Coupe  Two Seaters  2018
# 36969  Mercedes-Benz              AMG GT Coupe  Two Seaters  2018
# 36970  Mercedes-Benz           AMG GT Roadster  Two Seaters  2018
# 36971      Chevrolet                  Corvette  Two Seaters  2018
# 36972      Chevrolet                  Corvette  Two Seaters  2018
# 36973  Mercedes-Benz                  AMG SL63  Two Seaters  2018
# 36974  Mercedes-Benz                     SL550  Two Seaters  2018
# 36975      Chevrolet                  Corvette  Two Seaters  2018
# 36976      Chevrolet                  Corvette  Two Seaters  2018
# 36977        Ferrari             812 Superfast  Two Seaters  2018
# 36978  Mercedes-Benz                  AMG SL65  Two Seaters  2018
#
#       transmissiontype  transmissionspeeds  co2emissions
# 0            Automatic                   4    555.437500
# 1            Automatic                   4    555.437500
# 2            Automatic                   4    484.761905
# 3            Automatic                   4    424.166667
# 4            Automatic                   4    555.437500
# 5            Automatic                   4    484.761905
# 6            Automatic                   4    555.437500
# 7            Automatic                   3    467.736842
# 8            Automatic                   3    423.190476
# 9            Automatic                   3    444.350000
# 10           Automatic                   3    467.736842
# 11           Automatic                   3    493.722222
# 12           Automatic                   3    444.350000
# 13           Automatic                   3    467.736842
# 14           Automatic                   3    467.736842
# 15           Automatic                   3    424.166667
# 16           Automatic                   3    444.350000
# 17           Automatic                   3    467.736842
# 18           Automatic                   3    493.722222
# 19           Automatic                   3    444.350000
# 20           Automatic                   3    467.736842
# 21           Automatic                   3    444.350000
# 22           Automatic                   3    467.736842
# 23           Automatic                   3    423.190476
# 24           Automatic                   3    467.736842
# 25           Automatic                   3    493.722222
# 26           Automatic                   3    467.736842
# 27           Automatic                   3    444.350000
# 28           Automatic                   3    467.736842
# 29           Automatic                   3    424.166667
# ...                ...                 ...           ...
# 36949           Manual                   6    401.000000
# 36950        Automatic                   7    450.000000
# 36951        Automatic                   7    433.000000
# 36952        Automatic                   7    411.000000
# 36953        Automatic                   8    390.000000
# 36954        Automatic                   8    390.000000
# 36955        Automatic                   8    407.000000
# 36956        Automatic                   8    407.000000
# 36957        Automatic                   9    379.000000
# 36958           Manual                   6    476.000000
# 36959           Manual                   6    476.000000
# 36960           Manual                   6    485.000000
# 36961           Manual                   6    485.000000
# 36962           Manual                   6    447.000000
# 36963           Manual                   6    426.000000
# 36964        Automatic                   7    501.000000
# 36965        Automatic                   7    495.000000
# 36966        Automatic                   7    501.000000
# 36967        Automatic                   7    495.000000
# 36968        Automatic                   7    486.000000
# 36969        Automatic                   7    486.000000
# 36970        Automatic                   7    490.000000
# 36971        Automatic                   8    541.000000
# 36972        Automatic                   8    487.000000
# 36973        Automatic                   7    468.000000
# 36974        Automatic                   9    442.000000
# 36975           Manual                   7    466.000000
# 36976           Manual                   7    503.000000
# 36977        Automatic                   7    661.000000
# 36978        Automatic                   7    546.000000
#
# [36979 rows x 12 columns]

# %%
response = 'co2emissions'
y = vehicles[[response]]
y.head()
# Out:
#    co2emissions
# 0    555.437500
# 1    555.437500
# 2    484.761905
# 3    424.166667
# 4    555.437500

# %%
predictors = list(vehicles.columns)
predictors
# Out:
# ['citympg',
#  'cylinders',
#  'displacement',
#  'drive',
#  'highwaympg',
#  'make',
#  'model',
#  'class',
#  'year',
#  'transmissiontype',
#  'transmissionspeeds',
#  'co2emissions']

# %%
predictors.remove(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4f5051635149> in <module>
# ----> 1 predictors.remove(response)
#       2 predictors
#
# ValueError: list.remove(x): x not in list

# %%
predictors
# Out:
# ['citympg',
#  'cylinders',
#  'displacement',
#  'drive',
#  'highwaympg',
#  'make',
#  'model',
#  'class',
#  'year',
#  'transmissiontype',
#  'transmissionspeeds']

# %%
x = vehicles[predictors]
x.head()
# Out:
#    citympg  cylinders  displacement             drive  highwaympg      make  \
# 0     14.0          6           4.1     2-Wheel Drive        19.0     Buick
# 1     14.0          8           5.0     2-Wheel Drive        20.0     Buick
# 2     18.0          8           5.7     2-Wheel Drive        26.0     Buick
# 3     21.0          6           4.3  Rear-Wheel Drive        31.0  Cadillac
# 4     14.0          8           4.1  Rear-Wheel Drive        19.0  Cadillac
#
#                      model       class  year transmissiontype  \
# 0      Electra/Park Avenue  Large Cars  1984        Automatic
# 1      Electra/Park Avenue  Large Cars  1984        Automatic
# 2      Electra/Park Avenue  Large Cars  1984        Automatic
# 3  Fleetwood/DeVille (FWD)  Large Cars  1984        Automatic
# 4   Brougham/DeVille (RWD)  Large Cars  1984        Automatic
#
#    transmissionspeeds
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4

# %% [markdown]
# ## How to split data using Simple Random Sampling

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
x_train.shape
# Out:
# (22187, 11)

# %%
y_train.shape
# Out:
# (22187, 1)

# %%
x_test.shape
# Out:
# (14792, 11)

# %%
y_test.shape
# Out:
# (14792, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.4)
x_test.shape
# Out:
# (14792, 11)

# %% [markdown]
# ## How to split data using Stratified Random Sampling

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.01,
                                                    random_state = 1234)

# %%
x['drive'].value_counts(normalize = True)
# Out:
# Rear-Wheel Drive     0.356797
# Front-Wheel Drive    0.353552
# All-Wheel Drive      0.239893
# 4-Wheel Drive        0.036480
# 2-Wheel Drive        0.013278
# Name: drive, dtype: float64

# %%
x_test['drive'].value_counts(normalize = True)
# Out:
# Front-Wheel Drive    0.364865
# Rear-Wheel Drive     0.332432
# All-Wheel Drive      0.248649
# 4-Wheel Drive        0.035135
# 2-Wheel Drive        0.018919
# Name: drive, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.01, 
                                                    random_state = 1234,
                                                    stratify = x['drive'])

# %%
x_test['drive'].value_counts(normalize = True)
# Out:
# Rear-Wheel Drive     0.356757
# Front-Wheel Drive    0.354054
# All-Wheel Drive      0.240541
# 4-Wheel Drive        0.035135
# 2-Wheel Drive        0.013514
# Name: drive, dtype: float64
